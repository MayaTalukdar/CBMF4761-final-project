# %%
from BranchEvaluate import Evaluate

# %%
# ?Evaluate

# %%
data_pth = 'testingDataFinalOutput.txt' #note: this file is not formatted correctly
model_pth = 'saved_models/Best_Brancher.pth'

# %%
Fixed = Evaluate(data_pth, model_pth)

# %%
#note that because of improper formatting, both the actual BL and the normalized predicted BL
#are shown
for tree in Fixed:
    print(tree)
    print('\n')
# Out:
# [['2112210001', '2212210001', 29.0, 0.3081676959991455], ['1111111111', '2012210001', 51.0, 0.4105457067489624], ['1111111111', '2112210001', 51.0, 0.44926923513412476]]
#
#
# ...
